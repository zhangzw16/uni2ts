# %%
import datasets
import pyarrow.compute as pc
import numpy as np

from uni2ts.common.env import env
from uni2ts.data.builder.lotsa_v1 import (
    Buildings900KDatasetBuilder,
    BuildingsBenchDatasetBuilder,
    CloudOpsTSFDatasetBuilder,
    CMIP6DatasetBuilder,
    ERA5DatasetBuilder,
    GluonTSDatasetBuilder,
    LargeSTDatasetBuilder,
    LibCityDatasetBuilder,
    OthersLOTSADatasetBuilder,
    ProEnFoDatasetBuilder,
    SubseasonalDatasetBuilder,
)

# %% [markdown]
# In this notebook, we will see how to calculate the dataset weighting in the [pre-training dataset config file](../cli/conf/pretrain/data/lotsa_v1_weighted.yaml). We will see how to automatically generate this file to avoid excessive manual labor.

# %%
dataset_list = (
    Buildings900KDatasetBuilder.dataset_list
    + BuildingsBenchDatasetBuilder.dataset_list
    + CloudOpsTSFDatasetBuilder.dataset_list
    + CMIP6DatasetBuilder.dataset_list
    + ERA5DatasetBuilder.dataset_list
    + GluonTSDatasetBuilder.dataset_list
    + LargeSTDatasetBuilder.dataset_list
    + LibCityDatasetBuilder.dataset_list
    + OthersLOTSADatasetBuilder.dataset_list
    + ProEnFoDatasetBuilder.dataset_list
    + SubseasonalDatasetBuilder.dataset_list
)

# %% [markdown]
# 1. Obtain the weights of all dataset from all available datasets.

# %%
from pathlib import Path
import json

total_distances = {}

WEIGHTS_PATH = "/data/Blob_EastUS/v-zhenwzhang/tsfm_datasets/lotsa_weights"
path = Path(WEIGHTS_PATH)
# go through all folders in WEIGHTS_PATH
for folder in path.iterdir():
    # iterate through all files names in the folder
    if not folder.is_dir():
        continue
    for file in folder.iterdir():
        # check if .json file
        if file.suffix == ".json":
            # load json file and get the weights
            with open(file, "r") as f:
                distance = json.load(f)
            total_distances |= distance

print(total_distances)
# Out:
# {'sceaux': 0.13499212265014648, 'borealis': 0.20265986025333405, 'ideal': 0.2898980975151062, 'bdg-2_panther': 0.20341044664382935, 'bdg-2_fox': 0.20915815234184265, 'bdg-2_rat': 0.15185955166816711, 'bdg-2_bear': 0.2121816724538803, 'smart': 0.16377359628677368, 'lcl': 0.2011713683605194, 'cmip6_1850': 0.2656000256538391, 'cmip6_1855': 0.26432132720947266, 'cmip6_1860': 0.262317031621933, 'cmip6_1865': 0.2660820782184601, 'cmip6_1870': 0.26280030608177185, 'cmip6_1875': 0.2659946382045746, 'cmip6_1880': 0.26181861758232117, 'cmip6_1885': 0.26711806654930115, 'cmip6_1890': 0.2643161714076996, 'cmip6_1895': 0.26815423369407654, 'cmip6_1900': 0.2622115910053253, 'cmip6_1905': 0.2649420499801636, 'cmip6_1910': 0.25890663266181946, 'cmip6_1915': 0.2665177881717682, 'cmip6_1920': 0.25985220074653625, 'cmip6_1925': 0.264789879322052, 'cmip6_1930': 0.2657538950443268, 'cmip6_1935': 0.259886771440506, 'cmip6_1940': 0.26843950152397156, 'cmip6_1945': 0.26085537672042847, 'cmip6_1950': 0.2619962990283966, 'cmip6_1955': 0.26093992590904236, 'cmip6_1960': 0.26499542593955994, 'cmip6_1965': 0.2613477408885956, 'cmip6_1970': 0.26573964953422546, 'cmip6_1975': 0.25623205304145813, 'cmip6_1980': 0.2626940608024597, 'cmip6_1985': 0.2562180459499359, 'cmip6_1990': 0.2613624930381775, 'cmip6_1995': 0.25015681982040405, 'cmip6_2000': 0.262285977602005, 'cmip6_2005': 0.25853797793388367, 'cmip6_2010': 0.2510518431663513, 'azure_vm_traces_2017': 0.4348257780075073, 'borg_cluster_data_2011': 0.4164044260978699, 'alibaba_cluster_trace_2018': 0.3704977333545685, 'era5_1989': 0.15443894267082214, 'era5_1990': 0.15527558326721191, 'era5_1991': 0.1546468883752823, 'era5_1992': 0.15411612391471863, 'era5_1993': 0.15543290972709656, 'era5_1994': 0.15531480312347412, 'era5_1995': 0.1555083990097046, 'era5_1996': 0.15492795407772064, 'era5_1997': 0.15362732112407684, 'era5_1998': 0.15297673642635345, 'era5_1999': 0.1533682644367218, 'era5_2000': 0.15420113503932953, 'era5_2001': 0.15352733433246613, 'era5_2002': 0.15358994901180267, 'era5_2003': 0.15319640934467316, 'era5_2004': 0.15381808578968048, 'era5_2005': 0.15327702462673187, 'era5_2006': 0.15404999256134033, 'era5_2007': 0.15373997390270233, 'era5_2008': 0.1531054675579071, 'era5_2009': 0.15361133217811584, 'era5_2010': 0.15249964594841003, 'era5_2011': 0.15301565825939178, 'era5_2012': 0.15279027819633484, 'era5_2013': 0.1533745676279068, 'era5_2014': 0.15335704386234283, 'era5_2015': 0.1538364440202713, 'era5_2016': 0.15190067887306213, 'era5_2017': 0.15280096232891083, 'era5_2018': 0.15344791114330292, 'taxi_30min': 0.4800482392311096, 'uber_tlc_daily': 1.0, 'uber_tlc_hourly': 0.2830413281917572, 'wiki-rolling_nips': 0.31740602850914, 'london_smart_meters_with_missing': 0.20910030603408813, 'wind_farms_with_missing': 0.5545032024383545, 'wind_power': 0.3608901798725128, 'solar_power': 0.514168381690979, 'oikolab_weather': 0.21661734580993652, 'elecdemand': 0.1620144546031952, 'covid_mobility': 1.0, 'kaggle_web_traffic_weekly': 1.0, 'extended_web_traffic_with_missing': 0.30565887689590454, 'm5': 0.6131766438484192, 'm4_yearly': 1.0, 'm1_yearly': 1.0, 'm1_quarterly': 1.0, 'monash_m3_yearly': 1.0, 'monash_m3_quarterly': 1.0, 'tourism_yearly': 1.0, 'm4_hourly': 0.37318167090415955, 'm4_daily': 0.5274747610092163, 'm4_weekly': 0.5662069320678711, 'm4_monthly': 0.9933872818946838, 'm4_quarterly': 0.9992772936820984, 'm1_monthly': 1.0, 'monash_m3_monthly': 1.0, 'monash_m3_other': 1.0, 'nn5_daily_with_missing': 0.25689101219177246, 'nn5_weekly': 1.0, 'tourism_monthly': 1.0, 'tourism_quarterly': 1.0, 'cif_2016_6': 1.0, 'cif_2016_12': 1.0, 'traffic_hourly': 0.5337739586830139, 'traffic_weekly': 1.0, 'australian_electricity_demand': 0.20639260113239288, 'rideshare_with_missing': 1.0, 'saugeenday': 0.3371916115283966, 'sunspot_with_missing': 0.10862183570861816, 'temperature_rain_with_missing': 0.6211884617805481, 'vehicle_trips_with_missing': 1.0, 'weather': 0.445128858089447, 'car_parts_with_missing': 1.0,  ...

# %%
for dataset in dataset_list:
    if dataset not in total_distances:
        print(f"Dataset {dataset} not found in total_distances")
        total_distances[dataset] = 0.4
# Out:
# Dataset buildings_900k not found in total_distances

# %%
# def get_dataset_group(name):
#     if name.startswith("era5"):
#         return "era5"
#     if name.startswith("cmip6"):
#         return "cmip6"
#     if name.startswith("largest"):
#         return "largest"
#     return name

# # total_distances dict group datasets, if group use mean
# grouped_distances = {}

# for dataset, distance in total_distances.items():
#     group = get_dataset_group(dataset)
#     if group not in grouped_distances:
#         grouped_distances[group] = []
#     grouped_distances[group].append(distance)

# for group, distances in grouped_distances.items():
#     grouped_distances[group] = np.mean(distances)

# %% [markdown]
# 2. Some datasets have been split into smaller chunks for efficiency -- group them back together

# %%
# Define the parameter T to control the sampling ratio
T = 2.4  # You can adjust this to control the sharpness of the distance effect

# Calculate the sampling weights based on distances
dataset_names = list(total_distances.keys())
distances = np.array([total_distances[dataset] for dataset in dataset_names])

# Inverse the distances (closer datasets get higher weights)
inverse_distances = np.exp(-T * distances)  # Use exponential function for a smoother decay based on T

# Normalize the weights to make them sum to 1
sampling_weights = inverse_distances / inverse_distances.sum()

# Create a dictionary to map each dataset to its corresponding sampling weight
sampling_weight_map = {dataset: weight for dataset, weight in zip(dataset_names, sampling_weights)}

print("Final sampling weights:")
print(sampling_weight_map)
# Out:
# Final sampling weights:
# {'sceaux': 0.008956260397402526, 'borealis': 0.007613707211513147, 'ideal': 0.0061754294942996495, 'bdg-2_panther': 0.007600004169564883, 'bdg-2_fox': 0.007495885741649626, 'bdg-2_rat': 0.008600935220017768, 'bdg-2_bear': 0.00744168910987803, 'smart': 0.008358485386140752, 'lcl': 0.007640954911612925, 'cmip6_1850': 0.006546259424534958, 'cmip6_1855': 0.006566379942616081, 'cmip6_1860': 0.00659804235378829, 'cmip6_1865': 0.006538690265112224, 'cmip6_1870': 0.006590393993303604, 'cmip6_1875': 0.006540062592704978, 'cmip6_1880': 0.006605939612835756, 'cmip6_1885': 0.00652245284326, 'cmip6_1890': 0.0065664611950068275, 'cmip6_1895': 0.0065062529513486055, 'cmip6_1900': 0.006599712249039168, 'cmip6_1905': 0.006556605061689941, 'cmip6_1910': 0.00665226866736756, 'cmip6_1915': 0.006531856305052009, 'cmip6_1920': 0.00663718936898028, 'cmip6_1925': 0.006559000033974049, 'cmip6_1930': 0.006543842425370746, 'cmip6_1935': 0.0066366387064427535, 'cmip6_1940': 0.0065018000166729255, 'cmip6_1945': 0.0066212287448857415, 'cmip6_1950': 0.006603123206418805, 'cmip6_1955': 0.006619885314350289, 'cmip6_1960': 0.006555765199279924, 'cmip6_1965': 0.006613409231973479, 'cmip6_1970': 0.00654406615809144, 'cmip6_1975': 0.006695106862570773, 'cmip6_1980': 0.00659207468337439, 'cmip6_1985': 0.0066953319358928785, 'cmip6_1990': 0.0066131750873131, 'cmip6_1995': 0.006793440405050806, 'cmip6_2000': 0.006598534121886689, 'cmip6_2005': 0.006658157008610979, 'cmip6_2010': 0.006778863376164877, 'azure_vm_traces_2017': 0.004361220723582722, 'borg_cluster_data_2011': 0.004558361529399164, 'alibaba_cluster_trace_2018': 0.00508929496803963, 'era5_1989': 0.008547855266467173, 'era5_1990': 0.008530708928068238, 'era5_1991': 0.008543590355315617, 'era5_1992': 0.008554480411811925, 'era5_1993': 0.008527488481134016, 'era5_1994': 0.008529905990231023, 'era5_1995': 0.008525943659508279, 'era5_1996': 0.0085378291541264, 'era5_1997': 0.008564521789919375, 'era5_1998': 0.008577904907790042, 'era5_1999': 0.008569848317539736, 'era5_2000': 0.008552735247447391, 'era5_2001': 0.008566577250265264, 'era5_2002': 0.008565290002618313, 'era5_2003': 0.008573383699549186, 'era5_2004': 0.008560601547875505, 'era5_2005': 0.008571725110215207, 'era5_2006': 0.008555838246044566, 'era5_2007': 0.008562206541691094, 'era5_2008': 0.008575255132968999, 'era5_2009': 0.008564850446647777, 'era5_2010': 0.008587732381234447, 'era5_2011': 0.00857710366253541, 'era5_2012': 0.008581744377126055, 'era5_2013': 0.008569718676778625, 'era5_2014': 0.008570079101336265, 'era5_2015': 0.00856022437819126, 'era5_2016': 0.008600086304094506, 'era5_2017': 0.008581524327560134, 'era5_2018': 0.008568210329630593, 'taxi_30min': 0.003912662520187449, 'uber_tlc_daily': 0.0011233708669625615, 'uber_tlc_hourly': 0.006277894667245515, 'wiki-rolling_nips': 0.005780900112941112, 'london_smart_meters_with_missing': 0.007496926476243547, 'wind_farms_with_missing': 0.003272408250891937, 'wind_power': 0.005208007974828939, 'solar_power': 0.0036050287718686386, 'oikolab_weather': 0.007362887932560644, 'elecdemand': 0.008393849009290405, 'covid_mobility': 0.0011233708669625615, 'kaggle_web_traffic_weekly': 0.0011233708669625615, 'extended_web_traffic_with_missing': 0.00594620120854168, 'm5': 0.0028425738376978496, 'm4_yearly': 0.0011233708669625615, 'm1_yearly': 0.0011233708669625615, 'm1_quarterly': 0.0011233708669625615, 'monash_m3_yearly': 0.0011233708669625615, 'monash_m3_quarterly': 0.0011233708669625615, 'tourism_yearly': 0.0011233708669625615, 'm4_hourly': 0.005056617885248591, 'm4_daily': 0.0034917199649281833, 'm4_weekly': 0.0031817686801452736, 'm4_monthly': 0.001141341575736485, 'm4_quarterly': 0.001125321039090664, 'm1_monthly': 0.0011233708669625615, 'monash_m3_monthly': 0.0011233708669625615, 'monash_m3_other': 0.0011233708669625615, 'nn5_daily_with_missing': 0.006684526906256155, 'nn5_weekly': 0.0011233708669625615, 'tourism_monthly': 0.0011233708669625615, 'tourism_quarterly': 0.0011233708669625615, 'cif_2016 ...

# %%
sampling_weight_map
# Out:
# {'sceaux': 0.008956260397402526,
#  'borealis': 0.007613707211513147,
#  'ideal': 0.0061754294942996495,
#  'bdg-2_panther': 0.007600004169564883,
#  'bdg-2_fox': 0.007495885741649626,
#  'bdg-2_rat': 0.008600935220017768,
#  'bdg-2_bear': 0.00744168910987803,
#  'smart': 0.008358485386140752,
#  'lcl': 0.007640954911612925,
#  'cmip6_1850': 0.006546259424534958,
#  'cmip6_1855': 0.006566379942616081,
#  'cmip6_1860': 0.00659804235378829,
#  'cmip6_1865': 0.006538690265112224,
#  'cmip6_1870': 0.006590393993303604,
#  'cmip6_1875': 0.006540062592704978,
#  'cmip6_1880': 0.006605939612835756,
#  'cmip6_1885': 0.00652245284326,
#  'cmip6_1890': 0.0065664611950068275,
#  'cmip6_1895': 0.0065062529513486055,
#  'cmip6_1900': 0.006599712249039168,
#  'cmip6_1905': 0.006556605061689941,
#  'cmip6_1910': 0.00665226866736756,
#  'cmip6_1915': 0.006531856305052009,
#  'cmip6_1920': 0.00663718936898028,
#  'cmip6_1925': 0.006559000033974049,
#  'cmip6_1930': 0.006543842425370746,
#  'cmip6_1935': 0.0066366387064427535,
#  'cmip6_1940': 0.0065018000166729255,
#  'cmip6_1945': 0.0066212287448857415,
#  'cmip6_1950': 0.006603123206418805,
#  'cmip6_1955': 0.006619885314350289,
#  'cmip6_1960': 0.006555765199279924,
#  'cmip6_1965': 0.006613409231973479,
#  'cmip6_1970': 0.00654406615809144,
#  'cmip6_1975': 0.006695106862570773,
#  'cmip6_1980': 0.00659207468337439,
#  'cmip6_1985': 0.0066953319358928785,
#  'cmip6_1990': 0.0066131750873131,
#  'cmip6_1995': 0.006793440405050806,
#  'cmip6_2000': 0.006598534121886689,
#  'cmip6_2005': 0.006658157008610979,
#  'cmip6_2010': 0.006778863376164877,
#  'azure_vm_traces_2017': 0.004361220723582722,
#  'borg_cluster_data_2011': 0.004558361529399164,
#  'alibaba_cluster_trace_2018': 0.00508929496803963,
#  'era5_1989': 0.008547855266467173,
#  'era5_1990': 0.008530708928068238,
#  'era5_1991': 0.008543590355315617,
#  'era5_1992': 0.008554480411811925,
#  'era5_1993': 0.008527488481134016,
#  'era5_1994': 0.008529905990231023,
#  'era5_1995': 0.008525943659508279,
#  'era5_1996': 0.0085378291541264,
#  'era5_1997': 0.008564521789919375,
#  'era5_1998': 0.008577904907790042,
#  'era5_1999': 0.008569848317539736,
#  'era5_2000': 0.008552735247447391,
#  'era5_2001': 0.008566577250265264,
#  'era5_2002': 0.008565290002618313,
#  'era5_2003': 0.008573383699549186,
#  'era5_2004': 0.008560601547875505,
#  'era5_2005': 0.008571725110215207,
#  'era5_2006': 0.008555838246044566,
#  'era5_2007': 0.008562206541691094,
#  'era5_2008': 0.008575255132968999,
#  'era5_2009': 0.008564850446647777,
#  'era5_2010': 0.008587732381234447,
#  'era5_2011': 0.00857710366253541,
#  'era5_2012': 0.008581744377126055,
#  'era5_2013': 0.008569718676778625,
#  'era5_2014': 0.008570079101336265,
#  'era5_2015': 0.00856022437819126,
#  'era5_2016': 0.008600086304094506,
#  'era5_2017': 0.008581524327560134,
#  'era5_2018': 0.008568210329630593,
#  'taxi_30min': 0.003912662520187449,
#  'uber_tlc_daily': 0.0011233708669625615,
#  'uber_tlc_hourly': 0.006277894667245515,
#  'wiki-rolling_nips': 0.005780900112941112,
#  'london_smart_meters_with_missing': 0.007496926476243547,
#  'wind_farms_with_missing': 0.003272408250891937,
#  'wind_power': 0.005208007974828939,
#  'solar_power': 0.0036050287718686386,
#  'oikolab_weather': 0.007362887932560644,
#  'elecdemand': 0.008393849009290405,
#  'covid_mobility': 0.0011233708669625615,
#  'kaggle_web_traffic_weekly': 0.0011233708669625615,
#  'extended_web_traffic_with_missing': 0.00594620120854168,
#  'm5': 0.0028425738376978496,
#  'm4_yearly': 0.0011233708669625615,
#  'm1_yearly': 0.0011233708669625615,
#  'm1_quarterly': 0.0011233708669625615,
#  'monash_m3_yearly': 0.0011233708669625615,
#  'monash_m3_quarterly': 0.0011233708669625615,
#  'tourism_yearly': 0.0011233708669625615,
#  'm4_hourly': 0.005056617885248591,
#  'm4_daily': 0.0034917199649281833,
#  'm4_weekly': 0.0031817686801452736,
#  'm4_monthly': 0.001141341575736485,
#  'm4_quarterly': 0.001125321039090664,
#  'm1_monthly': 0.0011233708669625615,
#  'monash_m3_monthly': 0.0011233708669625615,
#  'monash_m3_other': 0.0011233708669625615,
#  'nn5_daily_with_missing': 0.006684526906256155,
#  'nn5_weekly': 0.0011233708669625615,
#  'tourism_monthly': 0.0011233708669625615,
#  'tourism_quarterly': 0.0011233708669625615,
#  'cif_2016_6': 0.0011233708669625615,
#  'cif_2016_12': 0.0011233708669625615,
#  'traffic_hourly': 0.0034393289064694834,
#  'traffic_weekly': 0.0011233708669625615,
#  'australian_electricity_demand': 0.007545803833748787,
#  'rideshare_with_missing': 0.0011233708669625615,
#  'saugeenday': 0.0055128073823898635,
#  'sunspot_with_missing': 0.009541411802204825,
#  'temperature_rain_with_missing': 0.0027884379363309272,
#  'vehicle_trips_with_missing': 0.0011233708669625615,
#  'weather': 0.004254701507005581,
#  'car_parts_with_missing': 0.0011233708669625615,
#  'fred_md': 0.0035692679449926858,
#  'pedestrian_counts': 0.004895723882976407,
#  'hospital': 0.0011233708669625615,
#  'covid_deaths': 0.0011233708669625615,
#  'kdd_cup_2018_with_missing': 0.008170118355906369,
#  'bitcoin_with_missing': 0.005967501990855876,
#  'us_births': 0.006945174244521767,
#  'largest_2017': 0.007103154866678141,
#  'largest_2018': 0.007192457227838744,
#  'largest_2019': 0.007127626857669595,
#  'largest_2020': 0.007096081154040511,
#  'largest_2021': 0.00698575698317466,
#  'BEIJING_SUBWAY_30MIN': 0.005526354240287123,
#  'HZMETRO': 0.007748281462754917,
#  'LOOP_SEATTLE': 0.004889494133263825,
#  'LOS_LOOP': 0.0020317738458908155,
#  'M_DENSE': 0.004442398215081315,
#  'PEMS03': 0.007161757344296045,
#  'PEMS04': 0.0070850715267774,
#  'PEMS07': 0.006493934357137313,
#  'PEMS08': 0.006964000249421403,
#  'PEMS_BAY': 0.002687889146191788,
#  'Q-TRAFFIC': 0.006914444453644305,
#  'SHMETRO': 0.007655488483963331,
#  'SZ_TAXI': 0.008114240077282215,
#  'kdd2022': 0.007083053880643823,
#  'godaddy': 0.0011233708669625615,
#  'favorita_sales': 0.0066973512298615185,
#  'favorita_transactions': 0.005633820883711833,
#  'restaurant': 0.0011233708669625615,
#  'hierarchical_sales': 0.00699781668827057,
#  'china_air_quality': 0.008498306245007522,
#  'beijing_air_quality': 0.009062337589619026,
#  'residential_load_power': 0.005196554116182464,
#  'residential_pv_power': 0.004198401378425706,
#  'cdc_fluview_ilinet': 0.003189084602249763,
#  'cdc_fluview_who_nrevss': 0.0019255941645353871,
#  'project_tycho': 0.002571269485190526,
#  'gfc12_load': 0.0077711937687427795,
#  'gfc14_load': 0.005007474082489727,
#  'gfc17_load': 0.005952262346464124,
#  'spain': 0.0074361106056563256,
#  'pdb': 0.006575615330583017,
#  'elf': 0.007451096288773003,
#  'bull': 0.00897610127609416,
#  'cockatoo': 0.009602855545470017,
#  'hog': 0.008768285823630626,
#  'covid19_energy': 0.006968660326630103,
#  'subseasonal': 0.008302242439693405,
#  'subseasonal_precip': 0.008148512048598448,
#  'buildings_900k': 0.004741406719124674}

# %% [markdown]
# 4. Finally, we can generate the YAML file required for the pre-training dataset with the appropriate `weight_map`.

# %%
for builder_cls in [
    Buildings900KDatasetBuilder,
    BuildingsBenchDatasetBuilder,
    CloudOpsTSFDatasetBuilder,
    CMIP6DatasetBuilder,
    ERA5DatasetBuilder,
    GluonTSDatasetBuilder,
    LargeSTDatasetBuilder,
    LibCityDatasetBuilder,
    OthersLOTSADatasetBuilder,
    ProEnFoDatasetBuilder,
    SubseasonalDatasetBuilder,
]:
    print(f"- _target_: uni2ts.data.builder.lotsa_v1.{builder_cls.__name__}")
    print("  datasets: ${cls_getattr:${._target_},dataset_list}")
    print("  weight_map:")
    for dataset in builder_cls.dataset_list:
        print(f"    {dataset}: {sampling_weight_map[dataset]}")
    print("  sample_time_series:")
    print("    _target_: uni2ts.data.dataset.SampleTimeSeriesType")
    print('    _args_: ["proportional"]')
# Out:
# - _target_: uni2ts.data.builder.lotsa_v1.Buildings900KDatasetBuilder
#   datasets: ${cls_getattr:${._target_},dataset_list}
#   weight_map:
#     buildings_900k: 0.004741406719124674
#   sample_time_series:
#     _target_: uni2ts.data.dataset.SampleTimeSeriesType
#     _args_: ["proportional"]
# - _target_: uni2ts.data.builder.lotsa_v1.BuildingsBenchDatasetBuilder
#   datasets: ${cls_getattr:${._target_},dataset_list}
#   weight_map:
#     sceaux: 0.008956260397402526
#     borealis: 0.007613707211513147
#     ideal: 0.0061754294942996495
#     bdg-2_panther: 0.007600004169564883
#     bdg-2_fox: 0.007495885741649626
#     bdg-2_rat: 0.008600935220017768
#     bdg-2_bear: 0.00744168910987803
#     smart: 0.008358485386140752
#     lcl: 0.007640954911612925
#   sample_time_series:
#     _target_: uni2ts.data.dataset.SampleTimeSeriesType
#     _args_: ["proportional"]
# - _target_: uni2ts.data.builder.lotsa_v1.CloudOpsTSFDatasetBuilder
#   datasets: ${cls_getattr:${._target_},dataset_list}
#   weight_map:
#     azure_vm_traces_2017: 0.004361220723582722
#     borg_cluster_data_2011: 0.004558361529399164
#     alibaba_cluster_trace_2018: 0.00508929496803963
#   sample_time_series:
#     _target_: uni2ts.data.dataset.SampleTimeSeriesType
#     _args_: ["proportional"]
# - _target_: uni2ts.data.builder.lotsa_v1.CMIP6DatasetBuilder
#   datasets: ${cls_getattr:${._target_},dataset_list}
#   weight_map:
#     cmip6_1850: 0.006546259424534958
#     cmip6_1855: 0.006566379942616081
#     cmip6_1860: 0.00659804235378829
#     cmip6_1865: 0.006538690265112224
#     cmip6_1870: 0.006590393993303604
#     cmip6_1875: 0.006540062592704978
#     cmip6_1880: 0.006605939612835756
#     cmip6_1885: 0.00652245284326
#     cmip6_1890: 0.0065664611950068275
#     cmip6_1895: 0.0065062529513486055
#     cmip6_1900: 0.006599712249039168
#     cmip6_1905: 0.006556605061689941
#     cmip6_1910: 0.00665226866736756
#     cmip6_1915: 0.006531856305052009
#     cmip6_1920: 0.00663718936898028
#     cmip6_1925: 0.006559000033974049
#     cmip6_1930: 0.006543842425370746
#     cmip6_1935: 0.0066366387064427535
#     cmip6_1940: 0.0065018000166729255
#     cmip6_1945: 0.0066212287448857415
#     cmip6_1950: 0.006603123206418805
#     cmip6_1955: 0.006619885314350289
#     cmip6_1960: 0.006555765199279924
#     cmip6_1965: 0.006613409231973479
#     cmip6_1970: 0.00654406615809144
#     cmip6_1975: 0.006695106862570773
#     cmip6_1980: 0.00659207468337439
#     cmip6_1985: 0.0066953319358928785
#     cmip6_1990: 0.0066131750873131
#     cmip6_1995: 0.006793440405050806
#     cmip6_2000: 0.006598534121886689
#     cmip6_2005: 0.006658157008610979
#     cmip6_2010: 0.006778863376164877
#   sample_time_series:
#     _target_: uni2ts.data.dataset.SampleTimeSeriesType
#     _args_: ["proportional"]
# - _target_: uni2ts.data.builder.lotsa_v1.ERA5DatasetBuilder
#   datasets: ${cls_getattr:${._target_},dataset_list}
#   weight_map:
#     era5_1989: 0.008547855266467173
#     era5_1990: 0.008530708928068238
#     era5_1991: 0.008543590355315617
#     era5_1992: 0.008554480411811925
#     era5_1993: 0.008527488481134016
#     era5_1994: 0.008529905990231023
#     era5_1995: 0.008525943659508279
#     era5_1996: 0.0085378291541264
#     era5_1997: 0.008564521789919375
#     era5_1998: 0.008577904907790042
#     era5_1999: 0.008569848317539736
#     era5_2000: 0.008552735247447391
#     era5_2001: 0.008566577250265264
#     era5_2002: 0.008565290002618313
#     era5_2003: 0.008573383699549186
#     era5_2004: 0.008560601547875505
#     era5_2005: 0.008571725110215207
#     era5_2006: 0.008555838246044566
#     era5_2007: 0.008562206541691094
#     era5_2008: 0.008575255132968999
#     era5_2009: 0.008564850446647777
#     era5_2010: 0.008587732381234447
#     era5_2011: 0.00857710366253541
#     era5_2012: 0.008581744377126055
#     era5_2013: 0.008569718676778625
#     era5_2014: 0.008570079101336265
#     era5_2015: 0.00856022437819126
#     era5_2016: 0.008600086304094506
#     era5_2017: 0.008581524327560134
#     era5_2018: 0.008568210329630593
#   sample_time_series:
#     _target_: uni2ts.data.dataset.SampleTimeSeriesType
#     _args_: ["proportional"]
# - _target_: uni2ts.data.builder.lotsa_v1.GluonTSDatasetBuilder
#   datasets: ${cls_getattr:${._target_},dataset_list}
#   weight_map:
#     taxi_30min: 0.003912662520187449
#     uber_tlc_daily: 0.0011233708669625615
#     uber_tlc_hourly: 0.006277894667245515
#     wiki-rolling_nips: 0.005780900112941112
#     london_smart_meters_with_missing: 0.007496926476243547
#     wind_farms_with_missing: 0.003272408250891937
#     wind_power: 0.005208007974828939
#     solar_power: 0.0036050287718686386
#     oikolab_weather: 0.007362887932560644
#     elecdemand: 0.008393849009290405
#     covid_mobility: 0.0011233708669625615
#     kaggle_web_traffic_weekly: 0.0011233708669625615
#     extended_web_traffic_with_missing: 0.00594620120854168
#     m5: 0.0028425738376978496
#     m4_yearly: 0.0011233708669625615
#     m1_yearly: 0.0011233708669625615
#     m1_quarterly: 0.0011233708669625615
#     monash_m3_yearly: 0.0011233708669625615
#     monash_m3_quarterly: 0.0011233708669625615
#     tourism_yearly: 0.0011233708669625615
#     m4_hourly: 0.005056617885248591
#     m4_daily: 0.0034917199649281833
#     m4_weekly: 0.0031817686801452736
#     m4_monthly: 0.001141341575736485
#     m4_quarterly: 0.001125321039090664
#     m1_monthly: 0.0011233708669625615
#     monash_m3_monthly: 0.0011233708669625615
#     monash_m3_other: 0.0011233708669625615
#     nn5_daily_with_missing: 0.006684526906256155
#     nn5_weekly: 0.0011233708669625615
#     tourism_monthly: 0.0011233708669625615
#     tourism_quarterly: 0.0011233708669625615
#     cif_2016_6: 0.0011233708669625615
#     cif_2016_12: 0.0011233708669625615
#     traffic_hourly: 0.0034393289064694834
#     traffic_weekly: 0.0011233708669625615
#     australian_electricity_demand: 0.007545803833748787
#     rideshare_with_missing: 0.0011233708669625615
#     saugeenday: 0.0055128073823898635
#     sunspot_with_missing: 0.009541411802204825
#     temperature_rain_with_missing: 0.0027884379363309272
#     vehicle_trips_with_missing: 0.0011233708669625615
#     weather: 0.004254701507005581
#     car_parts_with_missing: 0.0011233708669625615
#     fred_md: 0.0035692679449926858
#     pedestrian_counts: 0.004895723882976407
#     hospital: 0.0011233708669625615
#     covid_deaths: 0.0011233708669625615
#     kdd_cup_2018_with_missing: 0.008170118355906369
#     bitcoin_with_missing: 0.005967501990855876
#     us_births: 0.006945174244521767
#   sample_time_series:
#     _target_: uni2ts.data.dataset.SampleTimeSeriesType
#     _args_: ["proportional"]
# - _target_: uni2ts.data.builder.lotsa_v1.LargeSTDatasetBuilder
#   datasets: ${cls_getattr:${._target_},dataset_list}
#   weight_map:
#     largest_2017: 0.007103154866678141
#     largest_2018: 0.007192457227838744
#     largest_2019: 0.007127626857669595
#     largest_2020: 0.007096081154040511
#     largest_2021: 0.00698575698317466
#   sample_time_series:
#     _target_: uni2ts.data.dataset.SampleTimeSeriesType
#     _args_: ["proportional"]
# - _target_: uni2ts.data.builder.lotsa_v1.LibCityDatasetBuilder
#   datasets: ${cls_getattr:${._target_},dataset_list}
#   weight_map:
#     BEIJING_SUBWAY_30MIN: 0.005526354240287123
#     HZMETRO: 0.007748281462754917
#     LOOP_SEATTLE: 0.004889494133263825
#     LOS_LOOP: 0.0020317738458908155
#     M_DENSE: 0.004442398215081315
#     PEMS03: 0.007161757344296045
#     PEMS04: 0.0070850715267774
#     PEMS07: 0.006493934357137313
#     PEMS08: 0.006964000249421403
#     PEMS_BAY: 0.002687889146191788
#     Q-TRAFFIC: 0.006914444453644305
#     SHMETRO: 0.007655488483963331
#     SZ_TAXI: 0.008114240077282215
#   sample_time_series:
#     _target_: uni2ts.data.dataset.SampleTimeSeriesType
#     _args_: ["proportional"]
# - _target_: uni2ts.data.builder.lotsa_v1.OthersLOTSADatasetBuilder
#   datasets: ${cls_getattr:${._target_},dataset_list}
#   weight_map:
#     kdd2022: 0.007083053880643823
#     godaddy: 0.0011233708669625615
#     favorita_sales: 0.0066973512298615185
#     favorita_transactions: 0.005633820883711833
#     restaurant: 0.0011233708669625615
#     hierarchical_sales: 0.00699781668827057
#     china_air_quality: 0.008498306245007522
#     beijing_air_quality: 0.009062337589619026
#     residential_load_power: 0.005196554116182464
#     residential_pv_power: 0.004198401378425706
#     cdc_fluview_ilinet: 0.003189084602249763
#     cdc_fluview_who_nrevss: 0.0019255941645353871
#     project_tycho: 0.002571269485190526
#   sample_time_series:
#     _target_: uni2ts.data.dataset.SampleTimeSeriesType
#     _args_: ["proportional"]
# - _target_: uni2ts.data.builder.lotsa_v1.ProEnFoDatasetBuilder
#   datasets: ${cls_getattr:${._target_},dataset_list}
#   weight_map:
#     gfc12_load: 0.0077711937687427795
#     gfc14_load: 0.005007474082489727
#     gfc17_load: 0.005952262346464124
#     spain: 0.0074361106056563256
#     pdb: 0.006575615330583017
#     elf: 0.007451096288773003
#     bull: 0.00897610127609416
#     cockatoo: 0.009602855545470017
#     hog: 0.008768285823630626
#     covid19_energy: 0.006968660326630103
#   sample_time_series:
#     _target_: uni2ts.data.dataset.SampleTimeSeriesType
#     _args_: ["proportional"]
# - _target_: uni2ts.data.builder.lotsa_v1.SubseasonalDatasetBuilder
#   datasets: ${cls_getattr:${._target_},dataset_list}
#   weight_map:
#     subseasonal: 0.008302242439693405
#     subseasonal_precip: 0.008148512048598448
#   sample_time_series:
#     _target_: uni2ts.data.dataset.SampleTimeSeriesType
#     _args_: ["proportional"]
